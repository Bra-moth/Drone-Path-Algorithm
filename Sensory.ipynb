# %% [markdown]
# <a href="https://colab.research.google.com/github/Bra-moth/Drone-Path-Algorithm/blob/main/Sensory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install opencv-python

# %%
import cv2
import numpy as np
import time

# Simulated drone control functions
def move_towards(object_position):
    print(f"Moving towards object at position: {object_position}")

def move_away_from(object_position):
    print(f"Moving away from object at position: {object_position}")

def follow_object(object_position):
    print(f"Following object at position: {object_position}")

def maintain_distance(object_position):
    print(f"Maintaining distance from object at position: {object_position}")

def avoid_obstacles():
    print("Avoiding obstacles...")

def land_drone():
    print("Landing drone...")

# Object detection using OpenCV (simulating a moving object detector)
def detect_objects(frame):
    # Load pre-trained MobileNet SSD model for object detection (example)
    net = cv2.dnn.readNetFromCaffe("deploy.prototxt", "mobilenet_iter_73000.caffemodel")
    classes = ["background", "aeroplane", "bicycle", "bird", "boat", "bottle", "bus", "car", "cat", "chair", "cow", "diningtable", "dog", "horse", "motorbike", "person", "pottedplant", "sheep", "sofa", "train", "tvmonitor"]

    height, width = frame.shape[:2]
    blob = cv2.dnn.blobFromImage(frame, 0.007843, (300, 300), 127.5, 127.5, 127.5, True)
    net.setInput(blob)
    detections = net.forward()

    objects = []
    for i in range(detections.shape[2]):
        confidence = detections[0, 0, i, 2]
        if confidence > 0.2:  # Threshold for confidence
            idx = int(detections[0, 0, i, 1])
            if classes[idx] == 'person':  # Track persons or any specific object
                x1 = int(detections[0, 0, i, 3] * width)
                y1 = int(detections[0, 0, i, 4] * height)
                x2 = int(detections[0, 0, i, 5] * width)
                y2 = int(detections[0, 0, i, 6] * height)
                objects.append(((x1, y1), (x2, y2), classes[idx]))  # (Start, End) coordinates
    return objects

# Simulate drone behavior based on detected objects
def process_detected_objects(objects, instructor_command):
    if objects:
        for obj in objects:
            x1, y1 = obj[0]
            x2, y2 = obj[1]
            object_position = ((x1 + x2) / 2, (y1 + y2) / 2)  # Center of the object
            print(f"Detected object at {object_position}")

            if instructor_command == "avoid":
                move_away_from(object_position)
            elif instructor_command == "approach":
                move_towards(object_position)
            elif instructor_command == "follow":
                follow_object(object_position)
            elif instructor_command == "monitor":
                maintain_distance(object_position)
    else:
        print("No object detected!")

# Simulated main loop
def drone_main_loop():
    # Start video capture (simulating drone camera)
    cap = cv2.VideoCapture(0)  # Use 0 for webcam or a video file path for a pre-recorded video
    if not cap.isOpened():
        print("Error: Camera not found!")
        return

    # Infinite loop for drone operation
    while True:
        ret, frame = cap.read()
        if not ret:
            break

        # Detect objects in the frame
        objects = detect_objects(frame)

        # Simulate instructor command (you can change this dynamically)
        instructor_command = "follow"  # Simulate the instructor's command

        # Process detected objects and perform the instructed action
        process_detected_objects(objects, instructor_command)

        # Show the frame with detected objects (for visualization)
        for obj in objects:
import cv2
import numpy as np
import time

# Simulated drone control functions
def move_towards(object_position):
    print(f"Moving towards object at position: {object_position}")

def move_away_from(object_position):
    print(f"Moving away from object at position: {object_position}")

def follow_object(object_position):
    print(f"Following object at position: {object_position}")

def maintain_distance(object_position):
    print(f"Maintaining distance from object at position: {object_position}")

def avoid_obstacles():
    print("Avoiding obstacles...")

def land_drone():
    print("Landing drone...")

# Object detection using OpenCV (simulating a moving object detector)
def detect_objects(frame):
    # Load pre-trained MobileNet SSD model for object detection (example)
    # NOTE:  The following two lines will cause an error if the files are not present.
    #        You will need to download these files and put them in the current directory
    #        or provide the correct path to them.
    net = cv2.dnn.readNetFromCaffe("deploy.prototxt", "mobilenet_iter_73000.caffemodel")
    classes = ["background", "aeroplane", "bicycle", "bird", "boat", "bottle", "bus", "car", "cat", "chair", "cow", "diningtable", "dog", "horse", "motorbike", "person", "pottedplant", "sheep", "sofa", "train", "tvmonitor"]

    height, width = frame.shape[:2]
    blob = cv2.dnn.blobFromImage(frame, 0.007843, (300, 300), 127.5, 127.5, 127.5, True)
    net.setInput(blob)
    detections = net.forward()

    objects = []
    for i in range(detections.shape[2]):
        confidence = detections[0, 0, i, 2]
        if confidence > 0.2:  # Threshold for confidence
            idx = int(detections[0, 0, i, 1])
            if classes[idx] == 'person':  # Track persons or any specific object
                x1 = int(detections[0, 0, i, 3] * width)
                y1 = int(detections[0, 0, i, 4] * height)
                x2 = int(detections[0, 0, i, 5] * width)
                y2 = int(detections[0, 0, i, 6] * height)
                objects.append(((x1, y1), (x2, y2), classes[idx]))  # (Start, End) coordinates
    return objects

# Simulate drone behavior based on detected objects
def process_detected_objects(objects, instructor_command):
    if objects:
        for obj in objects:
            x1, y1 = obj[0]
            x2, y2 = obj[1]
            object_position = ((x1 + x2) / 2, (y1 + y2) / 2)  # Center of the object
            print(f"Detected object at {object_position}")

            if instructor_command == "avoid":
                move_away_from(object_position)
            elif instructor_command == "approach":
                move_towards(object_position)
            elif instructor_command == "follow":
                follow_object(object_position)
            elif instructor_command == "monitor":
                maintain_distance(object_position)
    else:
        print("No object detected!")

# Simulated main loop
def drone_main_loop():
    # Start video capture (simulating drone camera)
    cap = cv2.VideoCapture(0)  # Use 0 for webcam or a video file path for a pre-recorded video
    if not cap.isOpened():
        print("Error: Camera not found!")
        return

    # Infinite loop for drone operation
    while True:
        ret, frame = cap.read()
        if not ret:
            break

        # Detect objects in the frame
        objects = detect_objects(frame)

        # Simulate instructor command (you can change this dynamically)
        instructor_command = "follow"  # Simulate the instructor's command

        # Process detected objects and perform the instructed action
        process_detected_objects(objects, instructor_command)

        # Show the frame with detected objects (for visualization)
        for obj in objects:
            x1, y1 = obj[0]
            x2, y2 = obj[1]
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)

        cv2.imshow("Drone Feed", frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    drone_main_loop()
# Out:
#   File "<ipython-input-3-2da7b734923c>", line 93
#     import cv2
#               ^
# IndentationError: expected an indented block after 'for' statement on line 92

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5ad7e087-1858-49db-9695-199a99f57c9f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5ad7e087-1858-49db-9695-199a99f57c9f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
